# %%
import pandas as pd
import pickle
import seaborn as sns
import numpy as np
from kde_ebm.mixture_model import fit_all_gmm_models
from kde_ebm import mixture_model
from sSuStaIn.sEBMSustain import sEBMSustain, sEBMSustainData
import os
import numpy.ma as ma
from collections import Counter
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt
from matplotlib import cm
import pdb

# %%
def process_L(L, min_val=0):
    mx = ma.masked_less_equal(L,min_val)
    min_masked = mx.min(axis=0)
    L_new = mx.filled(fill_value=min_masked)
    return L_new

# %% [markdown]
# ### Read the pickled file

# %%
pickle_path = "/nethome/rtandon32/ebm/s-SuStain-outputs/sim_tadpole9_mixture_GMM/pickle_files/sim_tadpole9_subtype3.pickle"
with open(pickle_path, "rb") as input_file:
    pkl = pickle.load(input_file)

# %% [markdown]
# ### MCI and CN/AD data

# %%
cn_ad_path = "/home/rtandon32/ebm/ebm_experiments/experiment_scripts/real_data/dfMri_D12_ebm_final_n327.csv"
df_cnad = pd.read_csv(cn_ad_path)
mci_path = "/nethome/rtandon32/ebm/ebm_experiments/experiment_scripts/real_data/dfMri_D12_ebm_mci.csv"
df_mci = pd.read_csv(mci_path)
df_cnad["EXAMDATE"] = pd.to_datetime(df_cnad["EXAMDATE"])
df_mci["EXAMDATE"] = pd.to_datetime(df_mci["EXAMDATE"])
assert all(df_mci.columns == df_cnad.columns)

# %% [markdown]
# ### Get the mixture model for the CN/AD subjects

# %%
k=119
X = df_cnad.iloc[:,:k].values
bm_names = df_cnad.columns[:k].tolist()
y = df_cnad["DX"].map({"Dementia":1, "CN":0})
mm_fit = mixture_model.fit_all_gmm_models
mixture_models = mm_fit(X, y)
L_yes = np.zeros(X.shape)
L_no = np.zeros(X.shape)
for i in range(k):
    L_no[:, i], L_yes[:, i] = mixture_models[i].pdf(None, X[:, i])

L_no = process_L(L_no)
L_yes = process_L(L_yes)
# Out:
# /home/rtandon32/.conda/envs/sustain/lib/python3.9/site-packages/scipy/optimize/optimize.py:282: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   warnings.warn("Values in x were outside bounds during a "

# %% [markdown]
# ### Create a SuStaIn object to call the associated methods

# %%
# Create the SuStaIn object for the sEBM model
stage_sizes = [25,25,25,25,19]
N_startpoints           = 25
N_S_max                 = 3
rep = 20
N_iterations_MCMC_init = int(2e4)
N_iterations_MCMC       = int(5e5)  #Generally recommend either 1e5 or 1e6 (the latter may be slow though) in practice
n_stages = 5
min_clust_size = 8
p_absorb = 0.3
SuStaInLabels = df_cnad.columns[:k].tolist()
dataset_name            = 'sim_tadpole9'
output_dir              = '/home/rtandon32/ebm/s-SuStain-outputs'
sustainType             = 'mixture_GMM'
output_folder           = os.path.join(output_dir, dataset_name + '_' + sustainType)
use_parallel_startpoints = True
sustain = sEBMSustain(L_yes, L_no, n_stages, stage_sizes, min_clust_size, p_absorb, rep, SuStaInLabels, N_startpoints, N_S_max, N_iterations_MCMC_init, N_iterations_MCMC, output_folder, dataset_name, use_parallel_startpoints)

# %% [markdown]
# ### Get the prob mat for the mci subjects

# %%
# Get the prob mat for the mci subjects
X_mci = df_mci.iloc[:,:k].values
prob_mat_mci = mixture_model.get_prob_mat(X_mci, mixture_models)
L_no_mci = prob_mat_mci[:,:,0]
L_yes_mci = prob_mat_mci[:,:,1]
L_no_mci = process_L(L_no_mci)
L_yes_mci = process_L(L_yes_mci)

# %% [markdown]
# ### Subtype and Stage the MCI subjects

# %%
# Subtype and Stage the MCI subjects
last_N = 1000000
N_samples = 1000
sustainData_newData = sEBMSustainData(L_yes_mci, L_no_mci, n_stages)
samples_sequence = pkl["samples_sequence"][:,:,-last_N:]
samples_f = pkl["samples_f"][:,-last_N:]
shape_seq = pkl["shape_seq"]
temp_mean_f = np.mean(samples_f, axis=1)
ix = np.argsort(temp_mean_f)[::-1]

ml_subtype_mci, \
prob_ml_subtype_mci, \
ml_stage_mci, \
prob_ml_stage_mci, \
prob_subtype_mci, \
prob_stage_mci, \
prob_subtype_stage_mci = sustain.subtype_and_stage_individuals(sustainData_newData, shape_seq, samples_sequence, samples_f, N_samples)

# %% [markdown]
# ### Subtype and Stage CN/AD data

# %%
# subtype and stage CN/AD data

sustainData_cnad = sEBMSustainData(L_yes, L_no, n_stages)
samples_sequence = pkl["samples_sequence"][:,:,-last_N:]
samples_f = pkl["samples_f"][:,-last_N:]
shape_seq = pkl["shape_seq"]

ml_subtype_cnad, \
prob_ml_subtype_cnad, \
ml_stage_cnad, \
prob_ml_stage_cnad, \
prob_subtype_cnad, \
prob_stage_cnad, \
prob_subtype_stage_cnad = sustain.subtype_and_stage_individuals(sustainData_cnad, shape_seq, samples_sequence, samples_f, N_samples)

# %% [markdown]
# ### Prepare final dataframe which has subtype, stage, PTID, DX, and EXAMDATE for all subjects

# %%
# DataFrame for CN/AD subjects
array_subtype_stage_cnad = np.hstack([ml_subtype_cnad, ml_stage_cnad, y.values.reshape(-1,1)])
cnad_solved = pd.DataFrame(data=array_subtype_stage_cnad, columns=["subtype", "stage", "DX"])
cnad_solved[["PTID", "EXAMDATE"]] = df_cnad[["PTID", "EXAMDATE"]]

# %%
# DataFrame for MCI subjects
array_subtype_stage_mci = np.hstack([ml_subtype_mci, ml_stage_mci])
mci_solved = pd.DataFrame(data=array_subtype_stage_mci, columns=["subtype", "stage"])
mci_solved["DX"] = 2.0
mci_solved[["PTID", "EXAMDATE"]] = df_mci[["PTID", "EXAMDATE"]]
final_df = pd.concat([cnad_solved, mci_solved], axis=0)

# %%
final_df["DX"] = final_df["DX"].map({0.0:"Controls", 1.0:"AD", 2.0:"MCI"})

# %%
final_df
# Out:
#      subtype  stage        DX        PTID   EXAMDATE
# 0        1.0    2.0  Controls  002_S_0295 2006-11-02
# 1        1.0    1.0  Controls  002_S_0413 2007-06-01
# 2        2.0    3.0        AD  002_S_0619 2006-12-13
# 3        1.0    4.0  Controls  002_S_0685 2010-07-15
# 4        1.0    2.0        AD  002_S_0816 2008-01-28
# ..       ...    ...       ...         ...        ...
# 546      3.0    3.0       MCI  941_S_4100 2015-08-28
# 547      3.0    1.0       MCI  941_S_4187 2012-02-29
# 548      0.0    2.0       MCI  941_S_4377 2012-08-16
# 549      2.0    1.0       MCI  941_S_4420 2013-03-25
# 550      1.0    4.0       MCI  941_S_4764 2013-06-10
#
# [878 rows x 5 columns]

# %% [markdown]
# # Longitudinal data analysis

# %%
# Longitudinal data analysis
long_path = "/nethome/rtandon32/ebm/ebm_experiments/experiment_scripts/real_data/df12_longitudinal_ebm.csv"
df_long = pd.read_csv(long_path)
cnad_ptid = df_cnad["PTID"].tolist()
mci_ptid = df_mci["PTID"].tolist()
df_long_cnad = df_long[df_long["sid"].isin(cnad_ptid)]
df_long_mci = df_long[df_long["sid"].isin(mci_ptid)]

# %%
k = 119
prob_mat_mci_long = mixture_model.get_prob_mat(df_long_mci.iloc[:,:k].values, mixture_models)
L_no_mci_long = prob_mat_mci_long[:,:,0]
L_yes_mci_long = prob_mat_mci_long[:,:,1]
L_yes_mci_long = process_L(L_yes_mci_long)
L_no_mci_long = process_L(L_no_mci_long)

# %% [markdown]
# ### Subtype and Stage the MCI subjects

# %%
last_N = 1000000
N_samples = 1000
sustainData_mci_long = sEBMSustainData(L_yes_mci_long, L_no_mci_long, n_stages)
samples_sequence = pkl["samples_sequence"][:,:,-last_N:]
samples_f = pkl["samples_f"][:,-last_N:]
shape_seq = pkl["shape_seq"]
temp_mean_f = np.mean(samples_f, axis=1)
ix = np.argsort(temp_mean_f)[::-1]

# %% [markdown]
# ### Get subtype and stage fir the MCI longitudinal observations

# %%
ml_subtype_mci, \
prob_ml_subtype_mci, \
ml_stage_mci, \
prob_ml_stage_mci, \
prob_subtype_mci, \
prob_stage_mci, \
prob_subtype_stage_mci = sustain.subtype_and_stage_individuals(sustainData_mci_long, shape_seq, samples_sequence, samples_f, N_samples)

# %%
mci_long_subtype_stage = np.hstack([ml_subtype_mci, ml_stage_mci])
mci_long_subtype_stage = pd.DataFrame(mci_long_subtype_stage, columns=["subtype", "stage"])
mci_long_subtype_stage[["sid", "date"]] = df_long_mci.reset_index()[["sid", "date"]]
mci_long_subtype_stage["date"] = pd.to_datetime(mci_long_subtype_stage["date"])
df_followup = mci_long_subtype_stage
df_followup = df_followup.sort_values(["sid", "date"])

# %%
mci_ptid = pd.unique(df_followup["sid"]).tolist()

# %%
st_dict = dict(zip(final_df["PTID"], final_df["subtype"]))

# %% [markdown]
# ### Read the pdxconv file

# %%
pdxconv_path = "/home/rtandon32/ebm/ebm_experiments/experiment_scripts/adni_post_hoc/DXSUM_PDXCONV_ADNIALL_25Jan2024.csv"
df_pdxconv = pd.read_csv(pdxconv_path)
df_pdxconv["EXAMDATE"] = pd.to_datetime(df_pdxconv["EXAMDATE"])
df_pdxconv_mci =  df_pdxconv[df_pdxconv["PTID"].isin(mci_ptid)]

# %%
df_pdxconv_mci["cs_subtype"] = df_pdxconv_mci["PTID"].map(st_dict)
# Out:
# <ipython-input-69-66819531a494>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pdxconv_mci["cs_subtype"] = df_pdxconv_mci["PTID"].map(st_dict)

# %%
df_pdxconv_mci
# Out:
#        Phase      ID   RID        PTID  SITEID VISCODE VISCODE2     VISDATE  \
# 10     ADNI1      22    22  011_S_0022     107      bl       bl  2005-11-01
# 15     ADNI1      32    41  007_S_0041       2      bl       bl  2005-11-14
# 27     ADNI1      56    33  035_S_0033       6      bl       bl  2005-12-09
# 30     ADNI1      62    51  099_S_0051      45      bl       bl  2005-12-29
# 37     ADNI1      76   101  007_S_0101       2      bl       bl  2006-01-05
# ...      ...     ...   ...         ...     ...     ...      ...         ...
# 13438  ADNI3  175136  4513  041_S_4513      28      y5     m132  2023-04-17
# 13468  ADNI3  176432  4514  126_S_4514      46      y5     m138  2023-06-27
# 13485  ADNI3  177571  2249  052_S_2249      30    init      m90  2018-08-27
# 13506  ADNI3  179204  4210  127_S_4210      47      y5     m132  2022-10-04
# 13509  ADNI3  179531  4631  137_S_4631      54      y3     m102  2023-12-03
#
#          USERDATE   USERDATE2  ... DXPDES  DXPCOG  DXPATYP  DXDEP  DXOTHDEM  \
# 10     2005-11-02         NaN  ...   -4.0    -4.0     -4.0    NaN      -4.0
# 15     2005-11-14         NaN  ...   -4.0    -4.0     -4.0    NaN      -4.0
# 27     2005-12-21         NaN  ...   -4.0    -4.0     -4.0    NaN      -4.0
# 30     2006-01-03         NaN  ...   -4.0    -4.0     -4.0    NaN      -4.0
# 37     2006-01-09         NaN  ...   -4.0    -4.0     -4.0    NaN      -4.0
# ...           ...         ...  ...    ...     ...      ...    ...       ...
# 13438  2023-05-17  2023-05-17  ...    NaN     NaN      NaN    0.0       NaN
# 13468  2023-06-27  2023-06-27  ...    NaN     NaN      NaN    1.0       NaN
# 13485  2023-08-01  2023-08-01  ...    NaN     NaN      NaN    0.0       NaN
# 13506  2023-11-28  2023-11-28  ...    NaN     NaN      NaN    NaN       NaN
# 13509  2023-12-19  2023-12-19  ...    NaN     NaN      NaN    0.0       NaN
#
#        DXODES  DXCONFID  DIAGNOSIS           update_stamp cs_subtype
# 10       -4.0       4.0        NaN  2005-11-02 00:00:00.0        0.0
# 15       -4.0       4.0        NaN  2005-11-14 00:00:00.0        1.0
# 27       -4.0       4.0        NaN  2005-12-21 00:00:00.0        2.0
# 30       -4.0       4.0        NaN  2006-01-03 00:00:00.0        2.0
# 37       -4.0       3.0        NaN  2006-01-09 00:00:00.0        2.0
# ...       ...       ...        ...                    ...        ...
# 13438     NaN       NaN        2.0  2023-05-18 04:20:27.0        0.0
# 13468     NaN       NaN        2.0  2023-06-28 04:22:25.0        3.0
# 13485     NaN       NaN        2.0  2023-08-02 04:21:22.0        3.0
# 13506     NaN       NaN        NaN  2023-11-29 04:24:50.0        0.0
# 13509     NaN       NaN        3.0  2023-12-20 04:24:35.0        3.0
#
# [4062 rows x 46 columns]

# %%
def counts_from_table(table, ptid, fields):
    # table - dataframe
    # fields - list of columns
    # ptid - list of PTID (subjects)
    # vals - dictionary, where keys 
    # are the fields and vals are a 
    # list of their possible values
    ptid_dict = {}
    for pt in ptid:
        table_pt = table[table["PTID"].isin([pt])][fields]
        f_dict = {}
        for f in fields:
            f_dict[f] = table_pt[f].unique()
        ptid_dict[pt] = f_dict
    return ptid_dict

# %%
ptid_dict = counts_from_table(df_pdxconv_mci, mci_ptid, ["DXMCI", "DXOTHDEM"])

# %%
ptid_dict
# Out:
# {'002_S_0729': {'DXMCI': array([ 1., -4., nan]),
#   'DXOTHDEM': array([-4., nan])},
#  '002_S_0782': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '002_S_0954': {'DXMCI': array([ 1., -4.]), 'DXOTHDEM': array([-4.])},
#  '002_S_1155': {'DXMCI': array([ 1., nan]), 'DXOTHDEM': array([-4., nan])},
#  '002_S_1268': {'DXMCI': array([ 1., nan]), 'DXOTHDEM': array([-4., nan])},
#  '002_S_2073': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '002_S_4229': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '002_S_4237': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '002_S_4251': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '002_S_4447': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '002_S_4473': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '002_S_4521': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '002_S_4654': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '002_S_4746': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '003_S_0908': {'DXMCI': array([ 1., nan]), 'DXOTHDEM': array([-4., nan])},
#  '003_S_1057': {'DXMCI': array([ 1., -4., nan]),
#   'DXOTHDEM': array([-4., nan])},
#  '003_S_1074': {'DXMCI': array([ 1., nan]), 'DXOTHDEM': array([-4., nan])},
#  '003_S_1122': {'DXMCI': array([ 1., nan]), 'DXOTHDEM': array([-4., nan])},
#  '003_S_2374': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '003_S_4288': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '003_S_4354': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '005_S_0223': {'DXMCI': array([-4.,  1.]), 'DXOTHDEM': array([-4.])},
#  '005_S_0448': {'DXMCI': array([ 1., nan]), 'DXOTHDEM': array([-4., nan])},
#  '005_S_2390': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '005_S_4168': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '005_S_4185': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '006_S_0675': {'DXMCI': array([ 1., -4.]), 'DXOTHDEM': array([-4.])},
#  '006_S_1130': {'DXMCI': array([ 1., -4., nan]),
#   'DXOTHDEM': array([-4., nan])},
#  '006_S_4679': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '006_S_4713': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '006_S_4960': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '007_S_0041': {'DXMCI': array([ 1., -4.]), 'DXOTHDEM': array([-4.])},
#  '007_S_0101': {'DXMCI': array([ 1., -4., nan]),
#   'DXOTHDEM': array([-4., nan])},
#  '007_S_0128': {'DXMCI': array([ 1., -4., nan]),
#   'DXOTHDEM': array([-4., nan])},
#  '007_S_0293': {'DXMCI': array([ 1., -4.]), 'DXOTHDEM': array([-4.])},
#  '007_S_0414': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '007_S_0698': {'DXMCI': array([ 1., nan]), 'DXOTHDEM': array([-4., nan])},
#  '007_S_2394': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '007_S_4272': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '007_S_4467': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '007_S_4611': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '009_S_1030': {'DXMCI': array([ 1., nan]), 'DXOTHDEM': array([-4., nan])},
#  '009_S_2208': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '009_S_4324': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '009_S_4359': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '009_S_4388': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '009_S_4543': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '009_S_4741': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '009_S_4814': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '009_S_4903': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '009_S_5000': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '010_S_0904': {'DXMCI': array([ 1., -4.]), 'DXOTHDEM': array([-4.])},
#  '011_S_0022': {'DXMCI': array([-4.,  1.]), 'DXOTHDEM': array([-4.])},
#  '011_S_0326': {'DXMCI': array([ 1., -4.]), 'DXOTHDEM': array([-4.])},
#  '011_S_0362': {'DXMCI': array([ 1., -4.]), 'DXOTHDEM': array([-4.])},
#  '011_S_0861': {'DXMCI': array([ 1., -4.]), 'DXOTHDEM': array([-4.])},
#  '011_S_1080': {'DXMCI': array([ 1., nan]), 'DXOTHDEM': array([-4., nan])},
#  '011_S_1282': {'DXMCI': array([ 1., -4., nan]),
#   'DXOTHDEM': array([-4., nan])},
#  '011_S_2274': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '011_S_4235': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '011_S_4366': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '011_S_4547': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '011_S_4845': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '011_S_4893': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '012_S_0634': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '012_S_0917': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '012_S_0932': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '012_S_1009': {'DXMCI': array([-4.,  1.]), 'DXOTHDEM': array([-4.])},
#  '012_S_1165': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '012_S_1175': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '012_S_1321': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '012_S_4012': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '012_S_4128': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '012_S_4188': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '012_S_4849': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '012_S_4987': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '013_S_1120': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '013_S_1186': {'DXMCI': array([ 1., nan]), 'DXOTHDEM': array([-4., nan])},
#  '013_S_1275': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '013_S_2324': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '013_S_2389': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '013_S_4268': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '013_S_4395': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '013_S_4579': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '013_S_4595': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '013_S_4917': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '013_S_4985': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '014_S_0169': {'DXMCI': array([ 1., nan]), 'DXOTHDEM': array([-4., nan])},
#  '014_S_0557': {'DXMCI': array([ 1., nan]), 'DXOTHDEM': array([-4., nan])},
#  '014_S_0563': {'DXMCI': array([ 1., -4., nan]),
#   'DXOTHDEM': array([-4., nan])},
#  '016_S_0354': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '016_S_0702': {'DXMCI': array([ 1., -4., nan]),
#   'DXOTHDEM': array([-4., nan])},
#  '016_S_0769': {'DXMCI': array([ 1., -4.]), 'DXOTHDEM': array([-4.,  1.])},
#  '016_S_1092': {'DXMCI': array([ 1., -4.]), 'DXOTHDEM': array([-4.])},
#  '016_S_1121': {'DXMCI': array([ 1., -4.]), 'DXOTHDEM': array([-4.])},
#  '016_S_1138': {'DXMCI': array([ 1., -4.]), 'DXOTHDEM': array([-4.])},
#  '016_S_2007': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '016_S_2031': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '016_S_2284': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '016_S_4121': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '016_S_4584': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '016_S_4646': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '016_S_4902': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '016_S_5007': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '018_S_0087': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '018_S_0103': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '018_S_0155': {'DXMCI': array([ 1., -4.]), 'DXOTHDEM': array([-4.])},
#  '018_S_0406': {'DXMCI': array([ 1., -4.]), 'DXOTHDEM': array([-4.])},
#  '018_S_2133': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '018_S_2138': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '018_S_2155': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '018_S_2180': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '018_S_4597': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '018_S_4809': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '018_S_4868': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '018_S_4889': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '019_S_4285': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '019_S_4293': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '019_S_4680': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  
{'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '130_S_0285': {'DXMCI': array([ 1., nan]), 'DXOTHDEM': array([-4., nan])},
#  '130_S_0505': {'DXMCI': array([ 1., nan]), 'DXOTHDEM': array([-4., nan])},
#  '130_S_2373': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '130_S_2391': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '130_S_2403': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '130_S_4250': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '130_S_4294': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '130_S_4405': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '130_S_4415': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '130_S_4417': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '130_S_4605': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '130_S_4817': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '130_S_4883': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '130_S_4925': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '133_S_0629': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '133_S_0638': {'DXMCI': array([ 1., -4.]), 'DXOTHDEM': array([-4.])},
#  '133_S_0792': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '133_S_0912': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '135_S_4281': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '135_S_4309': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '135_S_4356': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '135_S_4406': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '135_S_4489': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '135_S_4566': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '135_S_4722': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '135_S_4723': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '135_S_5273': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '136_S_0107': {'DXMCI': array([ 1., nan]), 'DXOTHDEM': array([-4., nan])},
#  '136_S_0195': {'DXMCI': array([ 1., -4.]), 'DXOTHDEM': array([-4.])},
#  '136_S_0429': {'DXMCI': array([ 1., -4.]), 'DXOTHDEM': array([-4.])},
#  '136_S_0579': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '136_S_0695': {'DXMCI': array([ 1., -4., nan]),
#   'DXOTHDEM': array([-4., nan])},
#  '136_S_0874': {'DXMCI': array([ 1., -4.]), 'DXOTHDEM': array([-4.])},
#  '136_S_1227': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '137_S_0158': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '137_S_0443': {'DXMCI': array([ 1., -4.]), 'DXOTHDEM': array([-4.])},
#  '137_S_0481': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '137_S_0668': {'DXMCI': array([ 1., -4., nan]),
#   'DXOTHDEM': array([-4., nan])},
#  '137_S_0722': {'DXMCI': array([ 1., -4., nan]),
#   'DXOTHDEM': array([-4., nan])},
#  '137_S_0800': {'DXMCI': array([ 1., nan]), 'DXOTHDEM': array([-4., nan])},
#  '137_S_0825': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '137_S_0973': {'DXMCI': array([ 1., -4., nan]),
#   'DXOTHDEM': array([-4., nan])},
#  '137_S_1414': {'DXMCI': array([ 1., nan]), 'DXOTHDEM': array([-4., nan])},
#  '137_S_1426': {'DXMCI': array([1.]), 'DXOTHDEM': array([-4.])},
#  '137_S_4299': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '137_S_4331': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '137_S_4351': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '137_S_4536': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '137_S_4596': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '137_S_4623': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '137_S_4631': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '137_S_4678': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '137_S_4815': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '137_S_4816': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '137_S_4852': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '141_S_0915': {'DXMCI': array([ 1., -4., nan]),
#   'DXOTHDEM': array([-4., nan])},
#  '141_S_1052': {'DXMCI': array([ 1., nan]), 'DXOTHDEM': array([-4., nan])},
#  '141_S_1255': {'DXMCI': array([ 1., nan]), 'DXOTHDEM': array([-4., nan])},
#  '141_S_4053': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '141_S_4160': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '141_S_4232': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '141_S_4423': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '141_S_4426': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '141_S_4438': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '141_S_4456': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '153_S_2109': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '153_S_2148': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '153_S_4077': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '153_S_4133': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '153_S_4159': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '153_S_4621': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '153_S_4838': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '941_S_2060': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '941_S_4036': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '941_S_4100': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '941_S_4187': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '941_S_4377': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '941_S_4420': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])},
#  '941_S_4764': {'DXMCI': array([nan]), 'DXOTHDEM': array([nan])}}

# %%
# st = 0.0
# df_pdxconv_mci_st = df_pdxconv_mci[df_pdxconv_mci["cs_subtype"]==st]
table = df_pdxconv_mci.pivot_table(index='cs_subtype', columns='DXMDUE', 
                        aggfunc=len, fill_value=0)["PTID"]
table
# Out:
# DXMDUE      -4.0   1.0   2.0
# cs_subtype
# 0.0          124   996    38
# 1.0           20   906    54
# 2.0           37   485    23
# 3.0           43   635    56

# %%
table.sum().sum()
# Out:
# 4062

# %%
long_to_cs = df_followup.sort_values(["sid", "date"]).drop_duplicates(subset=["sid"])

# %%
df_followup.sort_values(["sid", "date"])
# Out:
#       subtype  stage         sid       date
# 1683      0.0    3.0  002_S_0729 2007-02-22
# 1339      0.0    3.0  002_S_0729 2007-09-05
# 1186      0.0    3.0  002_S_0729 2008-09-29
# 1433      0.0    3.0  002_S_0729 2009-08-13
# 721       3.0    2.0  002_S_0782 2007-04-11
# ...       ...    ...         ...        ...
# 211       2.0    1.0  941_S_4420 2013-03-25
# 1484      1.0    4.0  941_S_4764 2012-06-01
# 1416      1.0    4.0  941_S_4764 2012-08-20
# 2279      1.0    4.0  941_S_4764 2013-06-10
# 781       1.0    4.0  941_S_4764 2014-06-16
#
# [2283 rows x 4 columns]

# %%
final_df[final_df["DX"].isin(["MCI"])]
# Out:
#      subtype  stage   DX        PTID   EXAMDATE
# 0        0.0    3.0  MCI  002_S_0729 2007-02-22
# 1        3.0    2.0  MCI  002_S_0782 2008-10-17
# 2        0.0    4.0  MCI  002_S_0954 2007-05-03
# 3        1.0    1.0  MCI  002_S_1155 2012-12-20
# 4        3.0    3.0  MCI  002_S_1268 2007-09-21
# ..       ...    ...  ...         ...        ...
# 546      3.0    3.0  MCI  941_S_4100 2015-08-28
# 547      3.0    1.0  MCI  941_S_4187 2012-02-29
# 548      0.0    2.0  MCI  941_S_4377 2012-08-16
# 549      2.0    1.0  MCI  941_S_4420 2013-03-25
# 550      1.0    4.0  MCI  941_S_4764 2013-06-10
#
# [551 rows x 5 columns]

# %%
long_to_cs.merge(final_df[final_df["DX"].isin(["MCI"])], left_on=["sid", "date"], right_on=["PTID", "EXAMDATE"], how="inner")
# Out:
#     subtype_x  stage_x         sid       date  subtype_y  stage_y   DX  \
# 0         0.0      3.0  002_S_0729 2007-02-22        0.0      3.0  MCI
# 1         0.0      4.0  002_S_0954 2007-05-03        0.0      4.0  MCI
# 2         0.0      4.0  006_S_0675 2007-04-26        0.0      4.0  MCI
# 3         2.0      3.0  007_S_0101 2007-01-29        2.0      3.0  MCI
# 4         0.0      3.0  007_S_0128 2006-08-14        0.0      3.0  MCI
# ..        ...      ...         ...        ...        ...      ...  ...
# 78        1.0      1.0  137_S_0800 2011-08-30        1.0      1.0  MCI
# 79        3.0      2.0  137_S_0973 2007-05-22        3.0      2.0  MCI
# 80        1.0      1.0  137_S_4623 2013-05-13        1.0      1.0  MCI
# 81        3.0      1.0  137_S_4631 2013-06-17        3.0      1.0  MCI
# 82        3.0      3.0  941_S_4100 2015-08-28        3.0      3.0  MCI
#
#           PTID   EXAMDATE
# 0   002_S_0729 2007-02-22
# 1   002_S_0954 2007-05-03
# 2   006_S_0675 2007-04-26
# 3   007_S_0101 2007-01-29
# 4   007_S_0128 2006-08-14
# ..         ...        ...
# 78  137_S_0800 2011-08-30
# 79  137_S_0973 2007-05-22
# 80  137_S_4623 2013-05-13
# 81  137_S_4631 2013-06-17
# 82  941_S_4100 2015-08-28
#
# [83 rows x 9 columns]

# %%
df_followup.sort_values(["sid", "date"])
# Out:
#       subtype  stage         sid       date
# 1683      0.0    3.0  002_S_0729 2007-02-22
# 1339      0.0    3.0  002_S_0729 2007-09-05
# 1186      0.0    3.0  002_S_0729 2008-09-29
# 1433      0.0    3.0  002_S_0729 2009-08-13
# 721       3.0    2.0  002_S_0782 2007-04-11
# ...       ...    ...         ...        ...
# 211       2.0    1.0  941_S_4420 2013-03-25
# 1484      1.0    4.0  941_S_4764 2012-06-01
# 1416      1.0    4.0  941_S_4764 2012-08-20
# 2279      1.0    4.0  941_S_4764 2013-06-10
# 781       1.0    4.0  941_S_4764 2014-06-16
#
# [2283 rows x 4 columns]

# %%
pd.merge(df_followup, df_pdxconv, left_on="sid", right_on="PTID", how="inner")
# Out:
#        subtype  stage         sid       date  Phase    ID   RID        PTID  \
# 0          0.0    3.0  002_S_0729 2007-02-22  ADNI1   786   729  002_S_0729
# 1          0.0    3.0  002_S_0729 2007-02-22  ADNI1  2418   729  002_S_0729
# 2          0.0    3.0  002_S_0729 2007-02-22  ADNI1  3832   729  002_S_0729
# 3          0.0    3.0  002_S_0729 2007-02-22  ADNI1  5634   729  002_S_0729
# 4          0.0    3.0  002_S_0729 2007-02-22  ADNI1  5884   729  002_S_0729
# ...        ...    ...         ...        ...    ...   ...   ...         ...
# 17340      1.0    4.0  941_S_4764 2014-06-16  ADNI2  3404  4764  941_S_4764
# 17341      1.0    4.0  941_S_4764 2014-06-16  ADNI2  4620  4764  941_S_4764
# 17342      1.0    4.0  941_S_4764 2014-06-16  ADNI2  6588  4764  941_S_4764
# 17343      1.0    4.0  941_S_4764 2014-06-16  ADNI2  8884  4764  941_S_4764
# 17344      1.0    4.0  941_S_4764 2014-06-16  ADNI2  9912  4764  941_S_4764
#
#        SITEID VISCODE  ... DXPARK DXPDES DXPCOG DXPATYP DXDEP  DXOTHDEM  \
# 0         101      bl  ...   -4.0   -4.0   -4.0    -4.0   NaN      -4.0
# 1         101     m06  ...   -4.0   -4.0   -4.0    -4.0   NaN      -4.0
# 2         101     m12  ...   -4.0   -4.0   -4.0    -4.0   NaN      -4.0
# 3         101     m18  ...   -4.0   -4.0   -4.0    -4.0   NaN      -4.0
# 4         101     m24  ...   -4.0   -4.0   -4.0    -4.0   NaN      -4.0
# ...       ...     ...  ...    ...    ...    ...     ...   ...       ...
# 17340      58     v03  ...    0.0    NaN    NaN     NaN   0.0       NaN
# 17341      58     v05  ...    0.0    NaN    NaN     NaN   0.0       NaN
# 17342      58     v11  ...    0.0    NaN    NaN     NaN   0.0       NaN
# 17343      58     v21  ...    0.0    NaN    NaN     NaN   0.0       NaN
# 17344      58     v31  ...    0.0    NaN    NaN     NaN   0.0       NaN
#
#        DXODES  DXCONFID  DIAGNOSIS           update_stamp
# 0        -4.0       4.0        NaN  2006-08-03 00:00:00.0
# 1        -4.0       4.0        NaN  2007-03-21 00:00:00.0
# 2        -4.0       4.0        NaN  2007-09-27 00:00:00.0
# 3        -4.0       4.0        NaN  2008-08-08 00:00:00.0
# 4        -4.0       4.0        NaN  2008-10-03 00:00:00.0
# ...       ...       ...        ...                    ...
# 17340     NaN       NaN        NaN  2013-03-14 19:16:46.0
# 17341     NaN       NaN        NaN  2013-03-14 19:16:47.0
# 17342     NaN       NaN        NaN  2013-07-01 19:16:37.0
# 17343     NaN       NaN        NaN  2014-07-03 19:16:58.0
# 17344     NaN       NaN        NaN  2015-07-06 11:12:04.0
#
# [17345 rows x 49 columns]

# %%
pdxconv_path = "/home/rtandon32/ebm/ebm_experiments/experiment_scripts/adni_post_hoc/DXSUM_PDXCONV_ADNIALL_25Jan2024.csv"

# %%
df_pdxconv.shape
# Out:
# (13514, 45)
